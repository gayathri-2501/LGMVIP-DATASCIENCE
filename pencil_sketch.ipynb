# %%
from google.colab.patches import cv2_imshow

import cv2

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-b2b2767d-c7e3-4715-bf9f-70e57a445be7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2b2767d-c7e3-4715-bf9f-70e57a445be7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EiffelTower.jpg to EiffelTower.jpg

# %%
import matplotlib.image as mpimg
image=mpimg.imread("EiffelTower.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=730x487 at 0x7F386403D710>

# %%
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=730x487 at 0x7F3863737F90>

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=730x487 at 0x7F38637B10D0>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=730x487 at 0x7F38637B8650>

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch = dodgeV2(img_gray, img_smoothing)

cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=730x487 at 0x7F386372CED0>
